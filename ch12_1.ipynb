# %% [markdown]
# <a href="https://colab.research.google.com/github/kimpyeong-an/digital/blob/main/ch12_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as pit
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/di/Images/home3.jpg')
print(img.shape)
gimg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#pit.imshow (gimg1, cmap= 'gray')
cv2_imshow(gimg1)
# Out:
# (600, 800, 3)
# <PIL.Image.Image image mode=L size=800x600>

# %%
img2 = img.copy()

# %%
edges = cv2.Canny(gimg1, 100, 200)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=800x600>

# %%
lines = cv2.HoughLines(edges, 1, np.pi/180, 200)

for line in lines:
  rho, theta = line[0]
  a = np.cos(theta)
  b = np.sin(theta)
  x0 = a*rho
  y0 = b*rho

  x1, y1 = int(x0 + 1000*(-b)), int(y0 + 1000*(a))
  x2, y2 = int(x0 - 1000*(-b)), int(y0 - 1000*(a))

  cv2.line(img2, (x1, y1), (x2, y2), (0, 0, 255), 2)

cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=800x600>
