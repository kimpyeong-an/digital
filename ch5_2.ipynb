# %% [markdown]
# <a href="https://colab.research.google.com/github/kimpyeong-an/digital/blob/main/ch5_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
img = cv2.imread('/content/gdrive/My Drive/di/Images/gsy.jpg')
print(img.shape)
gimg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#pit.imshow (gimg1, cmap= 'gray')
cv2_imshow(gimg1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2825568154.py in <cell line: 0>()
#       1 img = cv2.imread('/content/gdrive/My Drive/di/Images/gsy.jpg')
# ----> 2 print(img.shape)
#       3 gimg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4 #pit.imshow (gimg1, cmap= 'gray')
#       5 cv2_imshow(gimg1)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
ouimg=cv2.medianBlur(gimg1,7)
cv2_imshow(ouimg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3712925524.py in <cell line: 0>()
# ----> 1 ouimg=cv2.medianBlur(gimg1,7)
#       2 cv2_imshow(ouimg)
#
# NameError: name 'gimg1' is not defined

# %%
outimg = cv2.medianBlur(gimg1,7)
cv2_imshow(outimg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4207969865.py in <cell line: 0>()
# ----> 1 outimg = cv2.medianBlur(gimg1,7)
#       2 cv2_imshow(outimg)
#
# NameError: name 'gimg1' is not defined
