# %% [markdown]
# <a href="https://colab.research.google.com/github/kimpyeong-an/digital/blob/main/ch08_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as pit
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
img = cv2.imread('/content/gdrive/My Drive/di/Images/facespn.bmp')
print(img.shape)
gimg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#pit.imshow (gimg1, cmap= 'gray')
cv2_imshow(gimg1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1485734474.py in <cell line: 0>()
#       1 img = cv2.imread('/content/gdrive/My Drive/di/Images/facespn.bmp')
# ----> 2 print(img.shape)
#       3 gimg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4 #pit.imshow (gimg1, cmap= 'gray')
#       5 cv2_imshow(gimg1)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
kernel = np.ones((3,3), np.uint8)
erosion = cv2.erode(gimg1, kernel, iterations=1)
cv2_imshow(erosion)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3741464815.py in <cell line: 0>()
#       1 kernel = np.ones((3,3), np.uint8)
# ----> 2 erosion = cv2.erode(gimg1, kernel, iterations=1)
#       3 cv2_imshow(erosion)
#
# NameError: name 'gimg1' is not defined

# %%
opening = cv2.dilate(gimg1, kernel, iterations=1)
cv2_imshow(opening)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2273914304.py in <cell line: 0>()
# ----> 1 opening = cv2.dilate(gimg1, kernel, iterations=1)
#       2 cv2_imshow(opening)
#
# NameError: name 'gimg1' is not defined

# %%
dilate2 = cv2.dilate(opening, kernel, iterations=2)
cv2_imshow(dilate2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1019348751.py in <cell line: 0>()
# ----> 1 dilate2 = cv2.dilate(opening, kernel, iterations=2)
#       2 cv2_imshow(dilate2)
#
# NameError: name 'opening' is not defined

# %%
erode2 = cv2.erode(dilate2, kernel, iterations=2)
cv2_imshow(erode2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2190600856.py in <cell line: 0>()
# ----> 1 erode2 = cv2.erode(dilate2, kernel, iterations=2)
#       2 cv2_imshow(erode2)
#
# NameError: name 'dilate2' is not defined
